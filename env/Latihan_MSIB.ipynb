# %% [markdown]
# ## Assigment Day 56

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("zoo.xlsx")
df.head(5)
# Out:
#        name  hair  feathers  eggs  milk  airborne  aquatic  predator  toothed  \
# 0  aardvark     1         0     0     1         0        0         1        1
# 1  antelope     1         0     0     1         0        0         0        1
# 2      bass     0         0     1     0         0        1         1        1
# 3      bear     1         0     0     1         0        0         1        1
# 4      boar     1         0     0     1         0        0         1        1
#
#    backbone  breathes  venomous  fins  legs  tail  domestic  catsize  type
# 0         1         1         0     0     4     0         0        1     1
# 1         1         1         0     0     4     1         0        1     1
# 2         1         0         0     1     0     1         0        0     4
# 3         1         1         0     0     4     0         0        1     1
# 4         1         1         0     0     4     1         0        1     1

# %%
print("Ridwana Septian Nurardian")
# Out:
# Ridwana Septian Nurardian
